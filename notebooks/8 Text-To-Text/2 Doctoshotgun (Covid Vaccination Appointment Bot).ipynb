# %% [markdown]
# ![virus](https://b3-onwater.at/wp-content/uploads/5859233-biology-cell-coronavirus-covid-life-microorganism-virus.png)
#
# This script lets you automatically book a vaccine slot on Doctolib in France and in Germany in the next seven days.
#
# Instructions:
# - Create an account on https://www.doctolib.de/ or https://www.doctolib.fr/
# - Fill in data apart from *twofa_code*
# - Submit the form
# - Check your email for the authentication code
# - Click [ CLONE ] (top right next to model title)
# - Enter authentication code into *twofa_code*
# - Submit and watch the logs. You should receive an email confirmation of the booking

# %%
vaccine = 'pfizer'  #@param ['pfizer', 'moderna', 'astrazeneca', 'janssen']
dose = 'third (booster)'  #@param ['first', 'second', 'third (booster)']
start_date = '07/12/2021'  #@param {type: "string"}
city = 'berlin' #@param {type: "string"}
country = 'de'  #@param ['de', 'fr']
doctolib_email = ''  #@param {type: "string"}
doctolib_password = ''  #@param {type: "string"}

# Leave this blank at the start. Once you submitted the form you should receive this code by email.
twofa_code = '' #@param {type: "string"}

# %%
# %cd /content
# !git clone https://github.com/rbignon/doctoshotgun.git
# %cd /content/doctoshotgun
# !pip install -r requirements.txt

dose_mapping = {
    "first":"",
    "second":"--only-second",
    "third (booster)":"--only-third"
}

vaccine_mapping = {
    "pfizer":"--pfizer",
    "janssen": "--janssen",
    "moderna": "--moderna",
    "astrazeneca": "--astrazeneca",
    "all":""
}

vaccine_flag = vaccine_mapping[vaccine]

dose_flag = dose_mapping[dose]


if len(twofa_code) > 2:
    print("2FA code provided")
    code_flag = f"--code {twofa_code}"
    # !echo python3 ./doctoshotgun.py {country} {city} {doctolib_email} {doctolib_password} {dose_flag} {code_flag}
    # !python3 ./doctoshotgun.py {country} {city} {doctolib_email} {doctolib_password} {dose_flag} {code_flag} -p 0 --start-date {start_date}
else:
    print("No 2FA code provided. Requesting")
    # !echo timeout 10s python3 ./doctoshotgun.py {country} {city} {doctolib_email} {doctolib_password} {dose_flag} 
    # !timeout 10s python3 ./doctoshotgun.py {country} {city} {doctolib_email} {doctolib_password} {dose_flag} -p 0 --start-date {start_date}
# Out:
# /content
# fatal: destination path 'doctoshotgun' already exists and is not an empty directory.
# /content/doctoshotgun
# Requirement already satisfied: woob in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (3.0)
# Requirement already satisfied: cloudscraper in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (1.2.58)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (0.4.4)
# Requirement already satisfied: Babel in /usr/local/lib/python3.7/dist-packages (from woob->-r requirements.txt (line 1)) (2.9.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from woob->-r requirements.txt (line 1)) (4.2.6)
# Requirement already satisfied: unidecode in /usr/local/lib/python3.7/dist-packages (from woob->-r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from woob->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from woob->-r requirements.txt (line 1)) (2.23.0)
# Requirement already satisfied: cssselect in /usr/local/lib/python3.7/dist-packages (from woob->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: html2text>=3.200 in /usr/local/lib/python3.7/dist-packages (from woob->-r requirements.txt (line 1)) (2020.1.16)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from woob->-r requirements.txt (line 1)) (3.13)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from woob->-r requirements.txt (line 1)) (7.1.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->woob->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->woob->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->woob->-r requirements.txt (line 1)) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->woob->-r requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from cloudscraper->-r requirements.txt (line 2)) (0.9.1)
# Requirement already satisfied: pyparsing>=2.4.7 in /usr/local/lib/python3.7/dist-packages (from cloudscraper->-r requirements.txt (line 2)) (3.0.6)
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.7/dist-packages (from Babel->woob->-r requirements.txt (line 1)) (2018.9)
# 2FA code provided
# python3 ./doctoshotgun.py de berlin kalam.ali@gmail.com botdemon00! --only-third --code 152752
# Starting to look for vaccine slots for Kalam Ali between 2021-12-07 and 2021-12-14...
# Vaccines: Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer, Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna
# Country: de
# This may take a few minutes/hours, be patient!
# [2021-12-03 11:45:18]
#
# Center Praxis Sibylle Katzenstein (Berlin):
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center Frau Dr. med. Natalie Pirkham (Berlin):
# – MVZ Dr. Kaleth & Kollegen...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#
#
# Center Herr Dr. med. Behrouz Kherad (Berlin):
# – Kardiologische Privatpraxis Dr. Kherad...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center Herr Prof. Dr. Andreas Kupsch (Berlin):
# Unable to find requested vaccines in motives
# Motives: Neupatient, Wiedervorstellung
#
#
# Center Herr Dr. med. Kay Spickschen (Berlin):
# Unable to find requested vaccines in motives
# Motives: Erstuntersuchung/Neupatient (NEUROLOGISCH), Folgeuntersuchung (NEUROLOGISCH), Erstuntersuchung/Neupatient (PSYCHIATRISCH), Folgeuntersuchung (PSYCHIATRISCH), Messung NLG/ENG/EMG Verdacht auf Polyneuropathie (PNP), keine allgemeine Sprechstunde, Messung NLG/ENG/EMG Verdacht auf Karpaltunnelsyndrom (CTS), keine allgemeine Sprechstunde, NLG/ENG/EMG Verdacht auf Sulcus-ulnaris-Syndrom (SUS), keine allgemeine Sprechstunde, Erstimpfung Covid-19 (BioNTech/Pfizer) inkl. Zweittermin, Erstimpfung Covid-19 (BioNTech/Pfizer), Auffrischimpfung Covid-19 (Moderna)
#
#
# Center Orthopädie Gropiusstadt (Berlin):
# Unable to find requested vaccines in motives
# Motives: Sprechstunde, Erstuntersuchung Neupatient:in, go on, Videosprechstunde - Bestandspatient, Covid Antikörper Status (kostenpflichtig)
#
#
# Center Frau Priv.-Doz. Dr. med. Annett Gauruder-Burmester (Berlin):
# – Interdisziplinäres Beckenbodenzentrum...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#
#
# Center Hausarztpraxis Osterberg / Thiele / Heijlen (Berlin):
# Motive Auffrischungsimpfung Covid-19 (BioNTech/Pfizer) not allowed for new patients at this center. Skipping vaccine...
# Motive Auffrischungsimpfung Covid-19 (Moderna) not allowed for new patients at this center. Skipping vaccine...
# Unable to find requested vaccines in motives
# Motives: Hautkrebsvorsorge / Hautkrebs-Screening, Sprechstunde, Kontrolluntersuchung / Wiedervorstellung, Gesundheits-Check-up ab 35 Jahren, Disease-Management-Programm (DMP), Kontrolluntersuchung / Wiedervorstellung, Gesundheits-Check-up, Ultraschall / Sonografie, Sprechstunde, Disease-Management-Programm (DMP), Covid-19 / Corona Nasen-Rachen-Abstrich (PCR-Test), Erstimpfung Covid-19 (BioNTech/Pfizer) inkl. Zweittermin, Zweitimpfung Covid-19 (BioNTech/Pfizer), Erstimpfung Covid-19 (BioNTech/Pfizer), Auffrischungsimpfung Covid-19 (BioNTech/Pfizer), Auffrischungsimpfung Covid-19 (Moderna)
#
#
# Center Bonedoctor Praxis für Orthopädie & Unfallchirurgie - Christian Rose & Baharak Djohar (Berlin):
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center Aubacke - Zahnarztpraxis Daniel und Pirk (Berlin):
# – Aubacke - Zahnarztpraxis Daniel und Pirk...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center Frau Dr. med. Kyung-Hee Mauß (Berlin):
# – Dr. med. K-H Mauß...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#
#
# Center Diabetes Berlin (Berlin):
# – Diabeteszentrum Kreuzberg...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center HNO Praxis Neukölln (Berlin):
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#
#
# Center Orthopädische Praxis Mitte (Berlin):
# – Orthopädische Praxis Mitte ...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center Frau Dr. med. Margrit Lock (Berlin):
# – Standort Spandau...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
# – Standort Friedenau...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#
#
# Center Herr Uwe Cha (Berlin):
# – Orthopädie Kreuzberg...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center Herr Dr. med. Rayk le Blond (Berlin):
# – Standort Friedenau...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
# – Standort Spandau...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#
#
# Center Frau Dr. med. Christina Linden (Berlin):
# – Lindenpraxis - Dr. med. Christina Linden...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center Herr Lars Uhlmann (Berlin):
# Unable to find requested vaccines in motives
# Motives: Erstuntersuchung Neupatient:in, Kontrolluntersuchung / Wiedervorstellung, Gesundheits-Check-up ab 35 Jahren, Disease-Management-Programm (DMP), Reiseimpfberatung, Hautkrebsvorsorge / Hautkrebs-Screening, J1 - 12. bis 14. Lebensjahr, J2 - 16. bis 17. Lebensjahr, Jugendarbeitsschutzuntersuchung, Videosprechstunde, Akute Beschwerden / Notfall, Gesundheitsuntersuchung 18-34 Jahre, Ärztliche Bescheinigung/ Atteste/ Anträge, Ernährungsmedizin
#
#
# Center Praxis am Rüdesheimer Platz (Berlin):
# – Praxis am Rüdesheimer Platz...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
# – Corona-Test-Praxis (nur Online-Termine)...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
# – Corona-Impfungen (nur Online-Termine)...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#
#
# Center Privatpraxis für integrative Medizin (Berlin):
# – Privatarztpraxis Dr. med. Michael Oppel...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
# – Privatpraxis Lucia Maria Braun...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center Frau Katrin Lang (Berlin):
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center frauen+vital / Frauenärztliches Gesundheits- und Vitalzentrum (Berlin):
# – Frauenärztliches Gesundheits- und Vitalzentrum...
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center Frau Dr. med. Mitra Flemming (Berlin):
# – Standort Spandau...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
# – Standort Friedenau...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#
#
# Center HNO Praxis - Frau Dr. Katrin Kirchhof (Berlin):
# – HNO-Praxis Katrin Kirchhof Neukölln...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#
#
# Center Hausarztpraxis Steglitz (Berlin):
# Motive Auffrischungsimpfung Covid-19 (BioNTech/Pfizer) not allowed for new patients at this center. Skipping vaccine...
# Motive > 60 Jahre: Auffrischungsimpfung Covid-19 (BioNTech-Pfizer)  not allowed for new patients at this center. Skipping vaccine...
# Motive Auffrischungsimpfung Covid-19 (Moderna) not allowed for new patients at this center. Skipping vaccine...
# Unable to find requested vaccines in motives
# Motives: Erstuntersuchung Neupatient:in, Kontrolluntersuchung / Wiedervorstellung, Gesundheits-Check-up ab 35 Jahren, Disease-Management-Programm (DMP), Reiseimpfberatung, Hautkrebsvorsorge / Hautkrebs-Screening, J1 - 12. bis 14. Lebensjahr, J2 - 16. bis 17. Lebensjahr, Jugendarbeitsschutzuntersuchung, Naturheilkunde, Videosprechstunde, Akute Beschwerden / Notfall, Gesundheitsuntersuchung 18-34 Jahre, Ärztliche Bescheinigung/ Atteste/ Anträge, Videosprechstunde - Bestandspatient, Videosprechstunde - Neupatient, Ernährungsmedizin, Krebsvorsorge Mann, COVID-19 / Infektsprechstunde Bestandspatient, Grippeschutzimpfung für Privatpatienten, Erstimpfung Covid-19 (BioNTech/Pfizer) inkl. Zweittermin, Zweitimpfung Covid-19 (BioNTech/Pfizer), Auffrischungsimpfung Covid-19 (BioNTech/Pfizer), > 60 Jahre: Auffrischungsimpfung Covid-19 (BioNTech-Pfizer) , Auffrischungsimpfung Covid-19 (Moderna)
#
#
# Center Frau Dr. med. Margrit Lock (Berlin):
# – Standort Spandau...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
# – Standort Friedenau...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#
#
# Center Herr Dr. med. Stefan Freise (Berlin):
# – Gastroenterologische Privatpraxis - Dr. Stefan Freise ...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center Internistische Hausarztpraxis - Dr. med. Florian Olshausen, Dr. med. Katharina Bohn (Berlin):
# – Internistische Hausarztpraxis - Dr. med. Florian Olshausen, Dr. med. Katharina Bohn...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#
#
# Center Orthopädiezentrum Berlin (Berlin):
# – Orthopädiezentrum Berlin...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#
#
# Center Praxis für Frauenheilkunde Tiergarten (Berlin):
# Motive Auffrischungsimpfung Covid-19 (BioNTech/Pfizer) not allowed for new patients at this center. Skipping vaccine...
# Unable to find requested vaccines in motives
# Motives: Erstuntersuchung Neupatient:in, Nachsorge- / Kontrolluntersuchung Frauenarzt, Krebsvorsorge einfach (ohne Ultraschall), Krebsvorsorge erweitert (mit Ultraschall), Beratungsgespräch / Zweitmeinung Frauenarzt, Zweitimpfung Covid-19 (BioNTech/Pfizer), Erstimpfung Covid-19 (BioNTech/Pfizer), Auffrischungsimpfung Covid-19 (BioNTech/Pfizer)
#
#
# Center Praxis Dr. Hübner & Dr. Utz - Praxis für Innere Medizin und Kardiologie (Berlin):
# – Standort Tempelhof...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
# – Praxis Dr. Hübner & Dr. Utz - Fachärzte für Kardiologie - PRENZLAUER BERG...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center Praxis Dr. Hübner & Dr. Utz - Praxis für Innere Medizin und Kardiologie (Berlin):
# – Standort Tempelhof...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
# – Praxis Dr. Hübner & Dr. Utz - Fachärzte für Kardiologie - PRENZLAUER BERG...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center Frau Dr. med. Anais Kohsow (Berlin):
# – Fachärzte am Ufer...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#
#
# Center Frau Dr. med. Ayse Malerczyk-Aktas (Berlin):
# Unable to find requested vaccines in motives
# Motives: Akute Beschwerden / Notfall, Kontrolluntersuchung / Wiedervorstellung, Impfung / Impftermin, Gesprächstermin, U2 - 3. bis 10. Lebenstag , U5 - 6. bis 7. Lebensmonat, U6 - 10. bis 12. Lebensmonat, U7 - 21. bis 24. Lebensmonat, U7a - 34. bis 36. Lebensmonat, U8 - 46. bis 48. Lebensmonat, U9 - 60. bis 64. Lebensmonat, U10 - 7. bis 8. Lebensjahr, U11 - 9. bis 10. Lebensjahr, J1 - 12. bis 14. Lebensjahr, J2 - 16. bis 17. Lebensjahr, Neurologische Untersuchung/ Beratung, Sprachdiagnostik, Sprechstunde
#
#
# Center Frau Ines Domaschk (Berlin):
# – MVZ Dr. Kaleth & Kollegen...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#
#
# Center Frau Dr. med. Christine Scheinkönig (Berlin):
# – Allgemeinmedizinische Praxis Dr. Scheinkönig...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center Praxis für Kinder- und Jugendmedizin - Dr. med. Schönbeck & Dipl. med. Rainer Schwitzkowski (Berlin):
# Unable to find requested vaccines in motives
# Motives: Neugeborenen-Bilirubin/Gelbsucht-Sprechstunde = keine U3!, max Buchungsalter 14 Tage!, U4 - 3. bis 4. Lebensmonat, U5 - 6. bis 7. Lebensmonat, U6 - 10. bis 12. Lebensmonat, U7 - 21. bis 24. Lebensmonat, U7a - 34. bis 36. Lebensmonat, U8 - 46. bis 48. Lebensmonat, U9 - 60. bis 64. Lebensmonat, U10 - 7. bis 8. Lebensjahr, U11 - 9. bis 10. Lebensjahr, J1 - 12. bis 14. Lebensjahr, J2 - 16. bis 17. Lebensjahr, Impfung / Impftermin, Hyposensibilisierung (SIT), Hüftultraschall , Akuttermin, Kitatauglichkeit, Tauglichkeit, Asthmanachschulung, Covid-19 / Corona Nasen-Rachen-Abstrich (PCR-Test), Erstimpfung Covid-19 (BioNTech/Pfizer) inkl. Zweittermin, Zweitimpfung Covid-19 (BioNTech/Pfizer), Erstimpfung Covid-19 (BioNTech/Pfizer)
#
#
# Center PRAXIS FÜR INNERE UND HAUSÄRZTLICHE MEDIZIN (Berlin):
# – Praxis für Innere und Hausärztliche Medizin...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#
#
# Center PRAXIS CARSTEN BECK (Berlin):
# – Praxis Carsten Beck...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center Frau Dr. med. Gülcan Kazak-Yildirim (Berlin):
# – HNO-Praxis Dr. med. G. Kazak-Yildirim...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
#
#
# Center Herr Dr. med. Detlef Kaleth (Berlin):
# Unable to find requested vaccines in motives
# Motives: Rücken / Wirbelsäule - Neupatient / Erstvorstellung, Rücken / Wirbelsäule - Folgeuntersuchung, Videosprechstunde - Bestandspatient, Videosprechstunde - Neupatient, Gelenke / Muskulatur / Extremitäten - Neupatient / Erstvorstellung, Gelenke / Muskulatur / Extremitäten - Folgeuntersuchung, Gelenke / Muskulatur / Extremitäten - OP Beratung, Akute Beschwerden / Notfall, Hand - Neupatient / Erstvorstellung, Hand - Folgeuntersuchung, Fuß - Neupatient / Erstvorstellung, Fuß - Folgeuntersuchung, Schmerztherapie - Neupatient / Erstvorstellung, Schmerztherapie - Folgeuntersuchung, Erstimpfung Covid-19 (AstraZeneca) inkl. Zweittermin, Zweitimpfung Covid-19 (AstraZeneca)
#
#
# Center Corona Impfzentren - Berlin (Berlin):
# – Messe Berlin/ Halle 21...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... Slot not found :(
# – Messe Berlin (Moderna)...
#   Vaccine Auffrischung.*Pfizer|Pfizer.*Auffrischung|Dritt.*Pfizer|Booster.*Pfizer... Slot not found :(
#   Vaccine Auffrischung.*Moderna|Moderna.*Auffrischung|Dritt.*Moderna|Booster.*Moderna... found!
#   ├╴ Best slot found: Sat Dec 11 16:45:00 2021
#   ├╴ Booking for Kalam Ali...
#   └╴ Booking status: True
#
# 💉 Booked! Congratulations.
