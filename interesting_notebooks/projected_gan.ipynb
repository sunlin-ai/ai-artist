# %% [markdown]
# <a href="https://colab.research.google.com/github/pollinations/hive/blob/main/interesting_notebooks/projected_gan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training Projected GAN
# This is a self-contained notebook for training Projected GAN.

# %% [markdown]
# ## Setup
#
# Make sure you're running a GPU runtime; if not, select "GPU" as the hardware accelerator in Runtime > Change Runtime Type in the menu.
#
# Now, get the repo and install missing dependencies.

# %%
# %%capture
# %%bash
# clone repo
git clone https://github.com/autonomousvision/projected_gan
pip install timm dill

# %%
# %cd projected_gan
# Out:
# /content/projected_gan

# %% [markdown]
# ## Data Preparation
# We need to download and prepare the data. In this example, we use the few-shot datasets of the [FastGAN repo](https://github.com/odegeasslbc/FastGAN-pytorch).

# %%
#!gdown --id 15pzZqDZY28zPCKcOHaLrDO9Hvdkwsk_R
#!gdown https://drive.google.com/file/d/18SeB3qNULXGn0sIzV2UOH8wDggltcVyL/view?usp=sharing

# %%
# !mkdir data
#!ffmpeg -i Chemical1.mp4 data/%5d.jpg
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %%
# %%bash
# #python dataset_tool.py --source=./data/ --dest=./data/sofia512.zip --resolution=256x --max-images=512

# %% [markdown]
# ## Training
#
# Now that the data is prepared, we can start training!  The training loop tracks FID, but the computations seems to lead to problems in colab. Hence, it is disable by default (```metrics=[]```). The loop also generates fixed noise samples after a defined amount of ticks, eg. below ```--snap=1```.

# %%
import os
import json
import re
import dnnlib

from training import training_loop
from torch_utils import training_stats
from train import init_dataset_kwargs
from metrics import metric_main

# %%
def launch_training(c, desc, outdir, rank=0):
    # Pick output directory.
    prev_run_dirs = []
    if os.path.isdir(outdir):
        prev_run_dirs = [x for x in os.listdir(outdir) if os.path.isdir(os.path.join(outdir, x))]

    matching_dirs = [re.fullmatch(r'\d{5}' + f'-{desc}', x) for x in prev_run_dirs if re.fullmatch(r'\d{5}' + f'-{desc}', x) is not None]
    print("checking whether to resume")
    if c.restart_every > 0 and len(matching_dirs) > 0:  # expect unique desc, continue in this directory
        assert len(matching_dirs) == 1, f'Multiple directories found for resuming: {matching_dirs}'
        c.run_dir = os.path.join(outdir, matching_dirs[0].group())
        print("resuming")
    else:                     # fallback to standard
        prev_run_ids = [re.match(r'^\d+', x) for x in prev_run_dirs]
        prev_run_ids = [int(x.group()) for x in prev_run_ids if x is not None]
        cur_run_id = max(prev_run_ids, default=-1) + 1
        c.run_dir = os.path.join(outdir, f'{cur_run_id:05d}-{desc}')
        assert not os.path.exists(c.run_dir)


    # Print options.
    print()
    print('Training options:')
    print(json.dumps(c, indent=2))
    print()
    print(f'Output directory:    {c.run_dir}')
    print(f'Number of GPUs:      {c.num_gpus}')
    print(f'Batch size:          {c.batch_size} images')
    print(f'Training duration:   {c.total_kimg} kimg')
    print(f'Dataset path:        {c.training_set_kwargs.path}')
    print(f'Dataset size:        {c.training_set_kwargs.max_size} images')
    print(f'Dataset resolution:  {c.training_set_kwargs.resolution}')
    print(f'Dataset labels:      {c.training_set_kwargs.use_labels}')
    print(f'Dataset x-flips:     {c.training_set_kwargs.xflip}')
    print()

    # Create output directory.
    print('Creating output directory...')
    os.makedirs(c.run_dir, exist_ok=c.restart_every > 0)
    with open(os.path.join(c.run_dir, 'training_options.json'), 'wt+') as f:
        json.dump(c, f, indent=2)

    # Start training
    dnnlib.util.Logger(file_name=os.path.join(c.run_dir, 'log.txt'), file_mode='a', should_flush=False)
    sync_device = torch.device('cuda', rank) if c.num_gpus > 1 else None
    training_stats.init_multiprocessing(rank=rank, sync_device=sync_device)
    training_loop.training_loop(rank=rank, **c)

# %%
def train(**kwargs):
    # Initialize config.
    opts = dnnlib.EasyDict(kwargs) # Command line arguments.
    c = dnnlib.EasyDict() # Main config dict.
    c.G_kwargs = dnnlib.EasyDict(class_name=None, z_dim=64, w_dim=128, mapping_kwargs=dnnlib.EasyDict())
    c.G_opt_kwargs = dnnlib.EasyDict(class_name='torch.optim.Adam', betas=[0,0.99], eps=1e-8)
    c.D_opt_kwargs = dnnlib.EasyDict(class_name='torch.optim.Adam', betas=[0,0.99], eps=1e-8)
    c.data_loader_kwargs = dnnlib.EasyDict(pin_memory=True, prefetch_factor=2)

    # Training set.
    c.training_set_kwargs, dataset_name = init_dataset_kwargs(data=opts.data)
    if opts.cond and not c.training_set_kwargs.use_labels:
        raise ValueError('--cond=True requires labels specified in dataset.json')
    c.training_set_kwargs.use_labels = opts.cond
    c.training_set_kwargs.xflip = opts.mirror

    # Hyperparameters & settings.
    c.num_gpus = opts.gpus
    c.batch_size = opts.batch
    c.batch_gpu = opts.batch_gpu or opts.batch // opts.gpus
    c.G_kwargs.channel_base = opts.cbase
    c.G_kwargs.channel_max = opts.cmax
    c.G_kwargs.mapping_kwargs.num_layers = 2
    c.G_opt_kwargs.lr = (0.002 if opts.cfg == 'stylegan2' else 0.0025) if opts.glr is None else opts.glr
    c.D_opt_kwargs.lr = opts.dlr
    c.metrics = opts.metrics
    c.total_kimg = opts.kimg
    c.kimg_per_tick = opts.tick
    c.image_snapshot_ticks = c.network_snapshot_ticks = opts.snap
    c.random_seed = c.training_set_kwargs.random_seed = opts.seed
    c.data_loader_kwargs.num_workers = opts.workers

    # Sanity checks.
    if c.batch_size % c.num_gpus != 0:
        raise ValueError('--batch must be a multiple of --gpus')
    if c.batch_size % (c.num_gpus * c.batch_gpu) != 0:
        raise ValueError('--batch must be a multiple of --gpus times --batch-gpu')
    if any(not metric_main.is_valid_metric(metric) for metric in c.metrics):
        raise ValueError('\n'.join(['--metrics can only contain the following values:'] + metric_main.list_valid_metrics()))

    # Base configuration.
    c.ema_kimg = c.batch_size * 10 / 32
    if opts.cfg == 'stylegan2':
        c.G_kwargs.class_name = 'pg_modules.networks_stylegan2.Generator'
        c.G_kwargs.fused_modconv_default = 'inference_only' # Speed up training by using regular convolutions instead of grouped convolutions.
        use_separable_discs = True

    elif opts.cfg == 'fastgan':
        c.G_kwargs = dnnlib.EasyDict(class_name='pg_modules.networks_fastgan.Generator', cond=opts.cond)
        c.G_opt_kwargs.lr = c.D_opt_kwargs.lr = 0.0002
        use_separable_discs = False

    # Restart.
    c.restart_every = opts.restart_every

    # Description string.
    desc = f'{opts.cfg:s}-{dataset_name:s}-gpus{c.num_gpus:d}-batch{c.batch_size:d}'
    if opts.desc is not None:
        desc += f'-{opts.desc}'

    # Projected and Multi-Scale Discriminators
    c.loss_kwargs = dnnlib.EasyDict(class_name='training.loss.ProjectedGANLoss')
    c.D_kwargs = dnnlib.EasyDict(
        class_name='pg_modules.discriminator.ProjectedDiscriminator',
        diffaug=True,
        interp224=(c.training_set_kwargs.resolution < 224),
        backbone_kwargs=dnnlib.EasyDict(),
    )

    c.D_kwargs.backbone_kwargs.cout = 64
    c.D_kwargs.backbone_kwargs.expand = True
    c.D_kwargs.backbone_kwargs.proj_type = 2
    c.D_kwargs.backbone_kwargs.num_discs = 4
    c.D_kwargs.backbone_kwargs.separable = use_separable_discs
    c.D_kwargs.backbone_kwargs.cond = opts.cond

    # Launch.
    launch_training(c=c, desc=desc, outdir=opts.outdir)

# %%
# start training!

train(
    outdir='training-runs', 
    cfg='fastgan',
    data='./data/sofia512.zip', 
    gpus=1, 
    batch=32, 
    cond=False, 
    mirror=1, 
    batch_gpu=4, 
    cbase=32768, 
    cmax=512, 
    glr=None, 
    dlr=0.002, 
    desc='', 
    metrics=[],
    kimg=10000, 
    tick=4, 
    snap=1, 
    seed=0, 
    workers=0,
    restart_every=999999,
)
# Out:
# checking whether to resume
# resuming
#
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "pg_modules.networks_fastgan.Generator",
#     "cond": false
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0002
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0002
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "prefetch_factor": 2,
#     "num_workers": 0
#   },
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "./data/sofia512.zip",
#     "use_labels": false,
#     "max_size": 35306,
#     "xflip": 1,
#     "resolution": 512,
#     "random_seed": 0
#   },
#   "num_gpus": 1,
#   "batch_size": 32,
#   "batch_gpu": 4,
#   "metrics": [],
#   "total_kimg": 10000,
#   "kimg_per_tick": 4,
#   "image_snapshot_ticks": 1,
#   "network_snapshot_ticks": 1,
#   "random_seed": 0,
#   "ema_kimg": 10.0,
#   "restart_every": 999999,
#   "loss_kwargs": {
#     "class_name": "training.loss.ProjectedGANLoss"
#   },
#   "D_kwargs": {
#     "class_name": "pg_modules.discriminator.ProjectedDiscriminator",
#     "diffaug": true,
#     "interp224": false,
#     "backbone_kwargs": {
#       "cout": 64,
#       "expand": true,
#       "proj_type": 2,
#       "num_discs": 4,
#       "separable": false,
#       "cond": false
#     }
#   },
#   "run_dir": "training-runs/00001-fastgan-sofia512-gpus1-batch32-"
# }
#
# Output directory:    training-runs/00001-fastgan-sofia512-gpus1-batch32-
# Number of GPUs:      1
# Batch size:          32 images
# Training duration:   10000 kimg
# Dataset path:        ./data/sofia512.zip
# Dataset size:        35306 images
# Dataset resolution:  512
# Dataset labels:      False
# Dataset x-flips:     1
#
# Creating output directory...
# Loading training set...
#
# Num images:  70612
# Image shape: [3, 512, 512]
# Label shape: [0]
#
# Constructing networks...
# Resuming from "training-runs/00001-fastgan-sofia512-gpus1-batch32-/network-snapshot.pkl"
#
# Generator              Parameters  Buffers  Output shape        Datatype
# ---                    ---         ---      ---                 ---
# mapping                -           -        [4, 1, 256]         float32
# synthesis.init.init    16785408    16385    [4, 2048, 4, 4]     float32
# synthesis.feat_8.0     -           -        [4, 2048, 8, 8]     float32
# synthesis.feat_8.1     37748736    20480    [4, 2048, 8, 8]     float32
# synthesis.feat_8.2     1           -        [4, 2048, 8, 8]     float32
# synthesis.feat_8.3     4096        4097     [4, 2048, 8, 8]     float32
# synthesis.feat_8.4     -           -        [4, 1024, 8, 8]     float32
# synthesis.feat_8.5     18874368    11264    [4, 2048, 8, 8]     float32
# synthesis.feat_8.6     1           -        [4, 2048, 8, 8]     float32
# synthesis.feat_8.7     4096        4097     [4, 2048, 8, 8]     float32
# synthesis.feat_8.8     -           -        [4, 1024, 8, 8]     float32
# synthesis.feat_16.0    -           -        [4, 1024, 16, 16]   float32
# synthesis.feat_16.1    9437184     10240    [4, 1024, 16, 16]   float32
# synthesis.feat_16.2    1           -        [4, 1024, 16, 16]   float32
# synthesis.feat_16.3    2048        2049     [4, 1024, 16, 16]   float32
# synthesis.feat_16.4    -           -        [4, 512, 16, 16]    float32
# synthesis.feat_16.5    4718592     5632     [4, 1024, 16, 16]   float32
# synthesis.feat_16.6    1           -        [4, 1024, 16, 16]   float32
# synthesis.feat_16.7    2048        2049     [4, 1024, 16, 16]   float32
# synthesis.feat_16.8    -           -        [4, 512, 16, 16]    float32
# synthesis.feat_32.0    -           -        [4, 512, 32, 32]    float32
# synthesis.feat_32.1    2359296     5120     [4, 512, 32, 32]    float32
# synthesis.feat_32.2    1           -        [4, 512, 32, 32]    float32
# synthesis.feat_32.3    1024        1025     [4, 512, 32, 32]    float32
# synthesis.feat_32.4    -           -        [4, 256, 32, 32]    float32
# synthesis.feat_32.5    1179648     2816     [4, 512, 32, 32]    float32
# synthesis.feat_32.6    1           -        [4, 512, 32, 32]    float32
# synthesis.feat_32.7    1024        1025     [4, 512, 32, 32]    float32
# synthesis.feat_32.8    -           -        [4, 256, 32, 32]    float32
# synthesis.feat_64.0    -           -        [4, 256, 64, 64]    float32
# synthesis.feat_64.1    1179648     2816     [4, 512, 64, 64]    float32
# synthesis.feat_64.2    1           -        [4, 512, 64, 64]    float32
# synthesis.feat_64.3    1024        1025     [4, 512, 64, 64]    float32
# synthesis.feat_64.4    -           -        [4, 256, 64, 64]    float32
# synthesis.feat_64.5    1179648     2816     [4, 512, 64, 64]    float32
# synthesis.feat_64.6    1           -        [4, 512, 64, 64]    float32
# synthesis.feat_64.7    1024        1025     [4, 512, 64, 64]    float32
# synthesis.feat_64.8    -           -        [4, 256, 64, 64]    float32
# synthesis.se_64.main   8454144     33536    [4, 256, 1, 1]      float32
# synthesis.se_64        -           -        [4, 256, 64, 64]    float32
# synthesis.feat_128.0   -           -        [4, 256, 128, 128]  float32
# synthesis.feat_128.1   589824      2560     [4, 256, 128, 128]  float32
# synthesis.feat_128.2   1           -        [4, 256, 128, 128]  float32
# synthesis.feat_128.3   512         513      [4, 256, 128, 128]  float32
# synthesis.feat_128.4   -           -        [4, 128, 128, 128]  float32
# synthesis.feat_128.5   294912      1408     [4, 256, 128, 128]  float32
# synthesis.feat_128.6   1           -        [4, 256, 128, 128]  float32
# synthesis.feat_128.7   512         513      [4, 256, 128, 128]  float32
# synthesis.feat_128.8   -           -        [4, 128, 128, 128]  float32
# synthesis.se_128.main  2113536     16768    [4, 128, 1, 1]      float32
# synthesis.se_128       -           -        [4, 128, 128, 128]  float32
# synthesis.feat_256.0   -           -        [4, 128, 256, 256]  float32
# synthesis.feat_256.1   147456      1280     [4, 128, 256, 256]  float32
# synthesis.feat_256.2   1           -        [4, 128, 256, 256]  float32
# synthesis.feat_256.3   256         257      [4, 128, 256, 256]  float32
# synthesis.feat_256.4   -           -        [4, 64, 256, 256]   float32
# synthesis.feat_256.5   73728       704      [4, 128, 256, 256]  float32
# synthesis.feat_256.6   1           -        [4, 128, 256, 256]  float32
# synthesis.feat_256.7   256         257      [4, 128, 256, 256]  float32
# synthesis.feat_256.8   -           -        [4, 64, 256, 256]   float32
# synthesis.se_256.main  528384      8384     [4, 64, 1, 1]       float32
# synthesis.se_256       -           -        [4, 64, 256, 256]   float32
# synthesis.feat_512.0   -           -        [4, 64, 512, 512]   float32
# synthesis.feat_512.1   36864       640      [4, 64, 512, 512]   float32
# synthesis.feat_512.2   1           -        [4, 64, 512, 512]   float32
# synthesis.feat_512.3   128         129      [4, 64, 512, 512]   float32
# synthesis.feat_512.4   -           -        [4, 32, 512, 512]   float32
# synthesis.feat_512.5   18432       352      [4, 64, 512, 512]   float32
# synthesis.feat_512.6   1           -        [4, 64, 512, 512]   float32
# synthesis.feat_512.7   128         129      [4, 64, 512, 512]   float32
# synthesis.feat_512.8   -           -        [4, 32, 512, 512]   float32
# synthesis.se_512.main  132096      4192     [4, 32, 1, 1]       float32
# synthesis.se_512       -           -        [4, 32, 512, 512]   float32
# synthesis.to_big       867         291      [4, 3, 512, 512]    float32
# ---                    ---         ---      ---                 ---
# Total                  105870961   165874   -                   -
#
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#
# ProjectedDiscriminator                                               Parameters  Buffers  Output shape       Datatype
# ---                                                                  ---         ---      ---                ---
# feature_network.pretrained.layer0.0                                  864         -        [4, 32, 256, 256]  float32
# feature_network.pretrained.layer0.1                                  64          65       [4, 32, 256, 256]  float32
# feature_network.pretrained.layer0.3                                  896         98       [4, 16, 256, 256]  float32
# feature_network.pretrained.layer0.4                                  13968       1062     [4, 24, 128, 128]  float32
# feature_network.pretrained.layer1.0                                  39712       1702     [4, 40, 64, 64]    float32
# feature_network.pretrained.layer2.0                                  198480      5289     [4, 80, 32, 32]    float32
# feature_network.pretrained.layer2.1                                  446784      7977     [4, 112, 32, 32]   float32
# feature_network.pretrained.layer3.0                                  1652640     18060    [4, 192, 16, 16]   float32
# feature_network.pretrained.layer3.1                                  605440      5251     [4, 320, 16, 16]   float32
# feature_network.scratch.layer0_ccm                                   1600        -        [4, 64, 128, 128]  float32
# feature_network.scratch.layer1_ccm                                   5248        -        [4, 128, 64, 64]   float32
# feature_network.scratch.layer2_ccm                                   28928       -        [4, 256, 32, 32]   float32
# feature_network.scratch.layer3_ccm                                   164352      -        [4, 512, 16, 16]   float32
# feature_network.scratch.layer3_csm.out_conv                          131328      -        [4, 256, 32, 32]   float32
# feature_network.scratch.layer2_csm.skip_add.activation_post_process  -           -        [4, 256, 32, 32]   float32
# feature_network.scratch.layer2_csm.out_conv                          32896       -        [4, 128, 64, 64]   float32
# feature_network.scratch.layer1_csm.skip_add.activation_post_process  -           -        [4, 128, 64, 64]   float32
# feature_network.scratch.layer1_csm.out_conv                          8256        -        [4, 64, 128, 128]  float32
# feature_network.scratch.layer0_csm.skip_add.activation_post_process  -           -        [4, 64, 128, 128]  float32
# feature_network.scratch.layer0_csm.out_conv                          4160        -        [4, 64, 256, 256]  float32
# discriminator.mini_discs.0.main                                      2829120     19269    [4, 1, 13, 13]     float32
# discriminator.mini_discs.1.main                                      2763392     18052    [4, 1, 13, 13]     float32
# discriminator.mini_discs.2.main                                      2631936     16643    [4, 1, 13, 13]     float32
# discriminator.mini_discs.3.main                                      2106880     13826    [4, 1, 13, 13]     float32
# discriminator                                                        -           -        [4, 676]           float32
# ---                                                                  ---         ---      ---                ---
# Total                                                                13666944    107294   -                  -
#
# Distributing across 1 GPUs...
# Setting up training phases...
# Exporting sample images...
# Initializing logs...
# Training for 10000 kimg...
#
# tick 32    kimg 132.0    time 6m 35s       sec/tick 355.1   sec/kimg 88.77   maintenance 40.1   cpumem 5.41   gpumem 10.48  reserved 13.84
# tick 33    kimg 136.0    time 12m 48s      sec/tick 353.0   sec/kimg 88.25   maintenance 19.5   cpumem 5.03   gpumem 8.50   reserved 9.83
# tick 34    kimg 140.0    time 19m 00s      sec/tick 353.0   sec/kimg 88.25   maintenance 19.5   cpumem 4.72   gpumem 8.50   reserved 9.83
# tick 35    kimg 144.0    time 25m 12s      sec/tick 352.4   sec/kimg 88.10   maintenance 19.6   cpumem 4.53   gpumem 8.50   reserved 9.83
# tick 36    kimg 148.0    time 31m 23s      sec/tick 351.3   sec/kimg 87.81   maintenance 19.5   cpumem 4.41   gpumem 8.50   reserved 9.83
# tick 37    kimg 152.0    time 37m 33s      sec/tick 351.1   sec/kimg 87.78   maintenance 19.5   cpumem 4.41   gpumem 8.50   reserved 9.83
# tick 38    kimg 156.0    time 43m 44s      sec/tick 351.3   sec/kimg 87.83   maintenance 19.7   cpumem 4.25   gpumem 8.50   reserved 9.83
# tick 39    kimg 160.0    time 49m 54s      sec/tick 351.5   sec/kimg 87.87   maintenance 17.7   cpumem 4.12   gpumem 8.50   reserved 9.83
# tick 40    kimg 164.0    time 56m 02s      sec/tick 351.8   sec/kimg 87.94   maintenance 16.3   cpumem 4.09   gpumem 8.50   reserved 9.83
# tick 41    kimg 168.0    time 1h 02m 09s   sec/tick 351.2   sec/kimg 87.79   maintenance 16.5   cpumem 4.15   gpumem 8.50   reserved 9.83
# tick 42    kimg 172.0    time 1h 08m 17s   sec/tick 351.1   sec/kimg 87.76   maintenance 16.5   cpumem 4.13   gpumem 8.50   reserved 9.83
# tick 43    kimg 176.0    time 1h 14m 25s   sec/tick 351.3   sec/kimg 87.82   maintenance 16.6   cpumem 4.12   gpumem 8.50   reserved 9.83
# Exception in callback BaseAsyncIOLoop._handle_events(18, 1)
# handle: <Handle BaseAsyncIOLoop._handle_events(18, 1)>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 452, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 481, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 431, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 239, in dispatch_shell
#     sys.stdout.flush()
#   File "/content/projected_gan/dnnlib/util.py", line 96, in flush
#     self.file.flush()
# OSError: [Errno 30] Read-only file system
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 452, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 481, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 431, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 239, in dispatch_shell
#     sys.stdout.flush()
#   File "/content/projected_gan/dnnlib/util.py", line 96, in flush
#     self.file.flush()
# OSError: [Errno 30] Read-only file system
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
#   File "/content/projected_gan/dnnlib/util.py", line 96, in flush
#     self.file.flush()
# OSError: [Errno 30] Read-only file system
# Call stack:
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.7/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/usr/lib/python3.7/asyncio/events.py", line 100, in _run
#     self._loop.call_exception_handler(context)
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 1645, in call_exception_handler
#     self.default_exception_handler(context)
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 1619, in default_exception_handler
#     logger.error('\n'.join(log_lines), exc_info=exc_info)
# Message: 'Exception in callback BaseAsyncIOLoop._handle_events(18, 1)\nhandle: <Handle BaseAsyncIOLoop._handle_events(18, 1)>'
# Arguments: ()
# Exception in callback BaseAsyncIOLoop._handle_events(18, 1)
# handle: <Handle BaseAsyncIOLoop._handle_events(18, 1)>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 452, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 481, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 431, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 239, in dispatch_shell
#     sys.stdout.flush()
#   File "/content/projected_gan/dnnlib/util.py", line 96, in flush
#     self.file.flush()
# OSError: [Errno 30] Read-only file system
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 452, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 481, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 431, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 239, in dispatch_shell
#     sys.stdout.flush()
#   File "/content/projected_gan/dnnlib/util.py", line 96, in flush
#     self.file.flush()
# OSError: [Errno 30] Read-only file system
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
#   File "/content/projected_gan/dnnlib/util.py", line 96, in flush
#     self.file.flush()
# OSError: [Errno 30] Read-only file system
# Call stack:
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.7/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/usr/lib/python3.7/asyncio/events.py", line 100, in _run
#     self._loop.call_exception_handler(context)
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 1645, in call_exception_handler
#     self.default_exception_handler(context)
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 1619, in default_exception_handler
#     logger.error('\n'.join(log_lines), exc_info=exc_info)
# Message: 'Exception in callback BaseAsyncIOLoop._handle_events(18, 1)\nhandle: <Handle BaseAsyncIOLoop._handle_events(18, 1)>'
# Arguments: ()
# Exception in callback BaseAsyncIOLoop._handle_events(18, 1)
# handle: <Handle BaseAsyncIOLoop._handle_events(18, 1)>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 452, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 481, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 431, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 239, in dispatch_shell
#     sys.stdout.flush()
#   File "/content/projected_gan/dnnlib/util.py", line 96, in flush
#     self.file.flush()
# OSError: [Errno 30] Read-only file system
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 452, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 481, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 431, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 239, in dispatch_shell
#     sys.stdout.flush()
#   File "/content/projected_gan/dnnlib/util.py", line 96, in flush
#     self.file.flush()
# OSError: [Errno 30] Read-only file system
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/usr/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
#   File "/content/projected_gan/dnnlib/util.py", line 96, in flush
#     self.file.flush()
# OSError: [Errno 30] Read-only file system
# Call stack:
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.7/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/usr/lib/python3.7/asyncio/events.py", line 100, in _run
#     self._loop.call_exception_handler(context)
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 1645, in call_exception_handler
#     self.default_exception_handler(context)
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 1619, in default_exception_handler
#     logger.error('\n'.join(log_lines), exc_info=exc_info)
# Message: 'Exception in callback BaseAsyncIOLoop._handle_events(18, 1)\nhandle: <Handle BaseAsyncIOLoop._handle_events(18, 1)>'
# Arguments: ()

# %% [markdown]
# To inspect the samples, click on the folder symbol on the left and navigate to
#
# ```projected_gan/training-runs/YOUR_RUN```
#
# The files ```fakesXXXXXX.png``` are the samples for a fixed noise vector at point.
